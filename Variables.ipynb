# %% [markdown]
# <a href="https://colab.research.google.com/github/dilni2004/Python/blob/main/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variables temporarily store data in computers' memory

price = 10  # integer

print(price)
# Out:
# 10

# %%
# can reset it like shown down below as python runs this program line by line

price = 20.8  # float

print(price)
# Out:
# 20.8

# %%
# Other variables

name = 'Dilni'
is_published = True

print (name)
print(is_published)
# Out:
# Dilni
# True

# %% [markdown]
# ## Exercise

# %% [markdown]
# We check in a patient named John Smith. He's 20 years old and is a new patient.
#
# Define the 3 variables in this statement

# %%
name = 'John Smith'
age = 20
new_patient = True



print(name, ' is a ', age, ' year old',
      ' new patient.' if new_patient else ' existing patient.')
# Out:
# John Smith  is a  20  year old  new patient.
