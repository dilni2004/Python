# %% [markdown]
# <a href="https://colab.research.google.com/github/dilni2004/Python/blob/main/Part_1_First_Python_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic print code

print('My name is Dilni!')
# Out:
# My name is Dilni!

# %%
# How to draw a dog

print('O-----')
print('  ||||')
# Out:
# O-----
#   ||||

# %%
# Intro to different variables

print('*' * 10)
# Out:
# **********

# %%
# Draw a cat

print('  ^ ___ ^')
print(' | O   O |     ~ meow meow')
print(' \   ^   /')
print('  ~~~0~~~      __')
print(' /       \   _/ /')
print('|         | / _/')
print('|   |  |  |/ /')
print('\|  |  |  / /')
print(' (__)--(__)-')
# Out:
#   ^ ___ ^
#  | O   O |     ~ meow meow
#  \   ^   /
#   ~~~0~~~      __
#  /       \   _/ /
# |         | / _/
# |   |  |  |/ /
# \|  |  |  / /
#  (__)--(__)-
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# <>:10: SyntaxWarning: invalid escape sequence '\|'
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:7: SyntaxWarning: invalid escape sequence '\ '
# <>:10: SyntaxWarning: invalid escape sequence '\|'
# /tmp/ipython-input-2104198336.py:5: SyntaxWarning: invalid escape sequence '\ '
#   print(' \   ^   /')
# /tmp/ipython-input-2104198336.py:7: SyntaxWarning: invalid escape sequence '\ '
#   print(' /       \   _/ /')
# /tmp/ipython-input-2104198336.py:10: SyntaxWarning: invalid escape sequence '\|'
#   print('\|  |  |  / /')
